# %% [markdown]
# # Week 2 Assessment Set 1

# %% [markdown]
# #### 1. The first five records from the customer.csv file

# %%
import pandas as pd

# %%
customer_data = pd.read_csv("customer.csv")
customer_data[0:5]
# Out:
#    ID     Sex  Number_Children  Age  Income Own_Car Address  \
# 0   1    Male                1   25   26000     Yes      QC
# 1   2    Male                2   37   42000      No      QC
# 2   3    Male                2   27   26500      No      QC
# 3   4    Male                3   56   77000     Yes  Manila
# 4   5  Female                4   30   32000      No  Manila
#
#    Credit_Bureau_Score Buy_Car
# 0                  650      No
# 1                  800     Yes
# 2                  650      No
# 3                  700     Yes
# 4                  300      No

# %% [markdown]
# #### 2. Data of customers who bought cars (Buy_Car =  Yes)

# %%
customer_data[customer_data.Buy_Car == "Yes"]
# Out:
#     ID     Sex  Number_Children  Age  Income Own_Car   Address  \
# 1    2    Male                2   37   42000      No        QC
# 3    4    Male                3   56   77000     Yes    Manila
# 6    7  Female                3   45   55000      No    Taguig
# 7    8  Female                2   35   37000      No    Makati
# 8    9  Female                1   32   34000      No  Marikina
# 12  13  Female                2   54   72000      No        QC
# 13  14  Female                3   48   58000      No    Taguig
# 17  18  Female                1   30   31500     Yes    Manila
#
#     Credit_Bureau_Score Buy_Car
# 1                   800     Yes
# 3                   700     Yes
# 6                   300     Yes
# 7                   550     Yes
# 8                   600     Yes
# 12                  450     Yes
# 13                  500     Yes
# 17                  345     Yes

# %% [markdown]
# #### 3. Age, income and number of children data of customers who did not buy cars

# %%
customer_data[customer_data.Buy_Car == "No"][['Age','Income','Number_Children']]
# Out:
#     Age  Income  Number_Children
# 0    25   26000                1
# 2    27   26500                2
# 4    30   32000                4
# 5    30   31500                5
# 9    28   28500                1
# 10   27   29000                2
# 14   29   31500                4
# 15   28   33000                2
# 16   30   32000                1
# 18   30   30000                1
# 19   30   32000                2

# %% [markdown]
# #### 4. Data of customers who bought cars and have an income greater than 30,000

# %%
customer_data[(customer_data.Buy_Car == "Yes") & (customer_data.Income > 30000)]
# Out:
#     ID     Sex  Number_Children  Age  Income Own_Car   Address  \
# 1    2    Male                2   37   42000      No        QC
# 3    4    Male                3   56   77000     Yes    Manila
# 6    7  Female                3   45   55000      No    Taguig
# 7    8  Female                2   35   37000      No    Makati
# 8    9  Female                1   32   34000      No  Marikina
# 12  13  Female                2   54   72000      No        QC
# 13  14  Female                3   48   58000      No    Taguig
# 17  18  Female                1   30   31500     Yes    Manila
#
#     Credit_Bureau_Score Buy_Car
# 1                   800     Yes
# 3                   700     Yes
# 6                   300     Yes
# 7                   550     Yes
# 8                   600     Yes
# 12                  450     Yes
# 13                  500     Yes
# 17                  345     Yes

# %% [markdown]
# #### 5. Store the data extracted in item 4 in empty.csv file

# %%
extracted_customer_data = customer_data[(customer_data.Buy_Car == "Yes") & (customer_data.Income > 30000)]
extracted_customer_data.to_csv("empty.csv", index = False)

extracted_customer_data_result = pd.read_csv("empty.csv")
print(extracted_customer_data_result)
# Out:
#    ID     Sex  Number_Children  Age  Income Own_Car   Address  \
# 0   2    Male                2   37   42000      No        QC
# 1   4    Male                3   56   77000     Yes    Manila
# 2   7  Female                3   45   55000      No    Taguig
# 3   8  Female                2   35   37000      No    Makati
# 4   9  Female                1   32   34000      No  Marikina
# 5  13  Female                2   54   72000      No        QC
# 6  14  Female                3   48   58000      No    Taguig
# 7  18  Female                1   30   31500     Yes    Manila
#
#    Credit_Bureau_Score Buy_Car
# 0                  800     Yes
# 1                  700     Yes
# 2                  300     Yes
# 3                  550     Yes
# 4                  600     Yes
# 5                  450     Yes
# 6                  500     Yes
# 7                  345     Yes

# %%
# for checking

check = pd.read_csv("empty.csv")
check
# Out:
#    ID     Sex  Number_Children  Age  Income Own_Car   Address  \
# 0   2    Male                2   37   42000      No        QC
# 1   4    Male                3   56   77000     Yes    Manila
# 2   7  Female                3   45   55000      No    Taguig
# 3   8  Female                2   35   37000      No    Makati
# 4   9  Female                1   32   34000      No  Marikina
# 5  13  Female                2   54   72000      No        QC
# 6  14  Female                3   48   58000      No    Taguig
# 7  18  Female                1   30   31500     Yes    Manila
#
#    Credit_Bureau_Score Buy_Car
# 0                  800     Yes
# 1                  700     Yes
# 2                  300     Yes
# 3                  550     Yes
# 4                  600     Yes
# 5                  450     Yes
# 6                  500     Yes
# 7                  345     Yes

# %% [markdown]
# I chose not to engage in the optional activity.
